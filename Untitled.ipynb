# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import pylab as p
#import matplotlib.axes3d as p3
import mpl_toolkits.mplot3d.axes3d as p3
#%matplotlib notebook

# %%
mesh0 = 'cmake-build-debug/Mesh0.dat'
mesh1 = 'cmake-build-debug/Mesh1.dat'
mesh2 = 'cmake-build-debug/Mesh2.dat'
erreur = 'cmake-build-debug/Erreur.dat'

plot0 = 'cmake-build-debug/plot0.dat'
plot1 = 'cmake-build-debug/plot1.dat'

# %%
M0 = np.loadtxt(mesh0, delimiter=',')
M2 = np.loadtxt(mesh1, delimiter=',')
Er = np.loadtxt(erreur, delimiter=',')

E = np.loadtxt(mesh2, delimiter=',')

plt.plot(M0[:,0],M0[:,1], 'r--')
#plt.plot(M1[:,0],M1[:,1],'b')
plt.plot(M2[:,0],M2[:,1],'g')

#plt.scatter(M0[:,0],M0[:,1])
#plt.scatter(M2[:,0],M2[:,1])
plt.show()

# %%
plt.plot(E[:,0],E[:,1],'g')

# %%
plt.plot(Er[:,0],Er[:,1],'g')
